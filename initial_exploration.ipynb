# %%
# Load necessary libraries and import the data
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
df = pd.read_csv('data/kc_house_data.csv', index_col=0)

# %%
# Check the columns and first few rows
df.head()
# Out:
#                   date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 7129300520  10/13/2014  221900.0         3       1.00         1180      5650
# 6414100192   12/9/2014  538000.0         3       2.25         2570      7242
# 5631500400   2/25/2015  180000.0         2       1.00          770     10000
# 2487200875   12/9/2014  604000.0         4       3.00         1960      5000
# 1954400510   2/18/2015  510000.0         3       2.00         1680      8080
#
#             floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520     1.0         NaN   0.0          3      7        1180
# 6414100192     2.0         0.0   0.0          3      7        2170
# 5631500400     1.0         0.0   0.0          3      6         770
# 2487200875     1.0         0.0   0.0          5      7        1050
# 1954400510     1.0         0.0   0.0          3      8        1680
#
#            sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# ...

# %%
df.describe()
# Out:
#        price target  num_bedrooms  num_bathrooms     sqft_home      sqft_lot  \
# count  2.159700e+04  21597.000000   21597.000000  21597.000000  2.159700e+04
# mean   5.402966e+05      3.373200       2.115826   2080.321850  1.509941e+04
# std    3.673681e+05      0.926299       0.768984    918.106125  4.141264e+04
# min    7.800000e+04      1.000000       0.500000    370.000000  5.200000e+02
# 25%    3.220000e+05      3.000000       1.750000   1430.000000  5.040000e+03
# 50%    4.500000e+05      3.000000       2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000       2.500000   2550.000000  1.068500e+04
# max    7.700000e+06     33.000000       8.000000  13540.000000  1.651359e+06
#
#          num_floors  waterfront_view        viewed     condition  \
# count  21597.000000     19221.000000  21534.000000  21597.000000
# mean       1.494096         0.007596      0.233863      3.409825
# std        0.539683         0.086825      0.765686      0.650546
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21597 entries, 7129300520 to 1523300157
# Data columns (total 20 columns):
# date sold                21597 non-null object
# price target             21597 non-null float64
# num_bedrooms             21597 non-null int64
# num_bathrooms            21597 non-null float64
# sqft_home                21597 non-null int64
# sqft_lot                 21597 non-null int64
# num_floors               21597 non-null float64
# waterfront_view          19221 non-null float64
# viewed                   21534 non-null float64
# condition                21597 non-null int64
# grade                    21597 non-null int64
# sqft_above_ground        21597 non-null int64
# sqft_basement            21597 non-null object
# yr_built                 21597 non-null int64
# yr_renovated             17755 non-null float64
# zipcode                  21597 non-null int64
# lat                      21597 non-null float64
# ...

# %%
df = df.rename(columns={'date': 'date sold',
                        'price': 'price target',
                        'bedrooms': 'num_bedrooms',
                        'bathrooms': 'num_bathrooms',
                        'sqft_living': 'sqft_home',
                        'sqft_lot': 'sqft_lot',
                        'floors': 'num_floors',
                        'waterfront': 'waterfront_view',
                        'view': 'viewed',
                        'condition': 'condition',
                        'grade': 'grade',
                        'sqft_above': 'sqft_above_ground',
                        'sqft_basement': 'sqft_basement',
                        'yr_built': 'yr_built',
                        'yr_renovated': 'yr_renovated',
                        'zipcode': 'zipcode',
                        'lat': 'lat',
                        'long': 'long',
                        'sqft_living15': 'sqft_home_15neighbors',
                        'sqft_lot15': 'sqft_lot_15neighbors'})

# %%
duplicate_rows_df = df[df.duplicated()]
print(duplicate_rows_df.shape)
# Out:
# (0, 20)

# %%
#No duplicate rows in the data set

# %%
print(df.isnull().sum())
# Out:
# date sold                   0
# price target                0
# num_bedrooms                0
# num_bathrooms               0
# sqft_home                   0
# sqft_lot                    0
# num_floors                  0
# waterfront_view          2376
# viewed                     63
# condition                   0
# grade                       0
# sqft_above_ground           0
# sqft_basement               0
# yr_built                    0
# yr_renovated             3842
# zipcode                     0
# lat                         0
# long                        0
# sqft_home_15neighbors       0
# sqft_lot_15neighbors        0
# dtype: int64
